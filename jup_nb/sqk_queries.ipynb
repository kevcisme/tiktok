# %% [markdown]
# # TikTok

# %%
#!pip install TikTokApi nest_asyncio --quiet

# %%
import pandas as pd
import psycopg2 as pg

from creds import *
from TikTokApi import TikTokApi
from tiktoknames import *

# note: jupyter has an issue with async that we have two event loops running 
# one in Jupyter and one in the tiktokapi library
# https://github.com/jupyter/notebook/issues/3397#issuecomment-376803076
# running the next few lines overcome
# that we have two event loops running - one in Jupyter and one in the 
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# Setting up a helper function to keep code dry

# %%
def db_query(table_name):
    ''' Given a table name, return back all columns and all rows for that table'''
    try:
        conn = pg.connect(host=the_host, database=the_database, user=the_user, password=the_password)
        curs = conn.cursor()
        curs.execute(f"""SELECT * FROM {table_name};""")
        datum = curs.fetchall()
        conn.close()
        return datum
    except pg.IntegrityError as e:
        print(e)

# %%
db_query('firsttable')
# Out:
# [('@fakeuser1', 'watched video', 'LIKED'),
#  ('@fakeuser2', 'watched video', 'WATCHED')]

# %%
db_query('information_schema.tables')
# Out:
# [('tiktokdb',
#   'public',
#   'firsttable',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statistic',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_type',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_foreign_server',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_authid',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_shadow',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statistic_ext_data',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_roles',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_settings',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_file_settings',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_hba_file_rules',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_config',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_cursors',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_user_mapping',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_bgwriter',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_replication_origin_status',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_subscription',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_progress_vacuum',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_progress_cluster',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_attribute',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_proc',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_class',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_attrdef',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_constraint',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_inherits',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_index',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_operator',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_opfamily',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_opclass',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_am',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_amop',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_amproc',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_language',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_largeobject_metadata',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_aggregate',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_progress_create_index',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_user_mappings',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_largeobject',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statistic_ext',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_rewrite',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_trigger',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_event_trigger',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_description',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_cast',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_enum',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_namespace',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_conversion',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_depend',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_database',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_db_role_setting',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_tablespace',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_pltemplate',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_auth_members',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_shdepend',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_shdescription',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_ts_config',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_ts_config_map',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_ts_dict',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_ts_parser',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_ts_template',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_extension',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_foreign_data_wrapper',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_foreign_table',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_policy',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_replication_origin',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_default_acl',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_init_privs',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_seclabel',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_shseclabel',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_collation',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_partitioned_table',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_range',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_transform',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_sequence',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_publication',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_publication_rel',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_subscription_rel',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_group',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_user',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_policies',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_rules',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_views',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_matviews',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_indexes',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_sequences',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stats',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stats_ext',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_publication_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_locks',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_available_extensions',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_available_extension_versions',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_prepared_xacts',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_prepared_statements',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_seclabels',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_sys_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_timezone_abbrevs',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_timezone_names',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_user_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_all_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_xact_all_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_sys_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_xact_sys_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_user_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_xact_user_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_all_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_all_indexes',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_sys_indexes',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_user_indexes',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_all_indexes',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_sys_indexes',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_user_indexes',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_all_sequences',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_sys_sequences',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_statio_user_sequences',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_activity',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_replication',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_wal_receiver',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_subscription',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_ssl',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_gssapi',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_replication_slots',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_database',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_database_conflicts',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_user_functions',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_xact_user_functions',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'pg_catalog',
#   'pg_stat_archiver',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'information_schema_catalog_name',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'check_constraint_routine_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'applicable_roles',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'administrable_role_authorizations',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'collation_character_set_applicability',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'attributes',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'check_constraints',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'character_sets',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'collations',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'column_domain_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'column_column_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'column_privileges',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'column_udt_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'columns',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'constraint_column_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'schemata',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'constraint_table_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'domain_constraints',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'sql_packages',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'domain_udt_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'sequences',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'domains',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'enabled_roles',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'key_column_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'parameters',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'referential_constraints',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'sql_features',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'role_column_grants',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'routine_privileges',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'role_routine_grants',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'routines',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'sql_implementation_info',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'sql_parts',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'sql_languages',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'sql_sizing',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'sql_sizing_profiles',
#   'BASE TABLE',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'YES',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'table_constraints',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'table_privileges',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'role_table_grants',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'views',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'transforms',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'triggered_update_columns',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   '_pg_foreign_servers',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'triggers',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'data_type_privileges',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'udt_privileges',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'role_udt_grants',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'usage_privileges',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'element_types',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'role_usage_grants',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'user_defined_types',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   '_pg_foreign_table_columns',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'view_column_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'view_routine_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'view_table_usage',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'foreign_server_options',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'column_options',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   '_pg_foreign_data_wrappers',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'foreign_data_wrapper_options',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'foreign_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'foreign_data_wrappers',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'foreign_servers',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   '_pg_foreign_tables',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'foreign_table_options',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   '_pg_user_mappings',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'user_mappings',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None),
#  ('tiktokdb',
#   'information_schema',
#   'user_mapping_options',
#   'VIEW',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'NO',
#   'NO',
#   None)]

# %%
db_query('user_mappings')
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# <ipython-input-14-1e43e8166569> in <module>
# ----> 1 db_query('user_mappings')
#
# <ipython-input-5-c008eb87dead> in db_query(table_name)
#       4         conn = pg.connect(host=the_host, database=the_database, user=the_user, password=the_password)
#       5         curs = conn.cursor()
# ----> 6         curs.execute(f"""SELECT *FROM {table_name};""")
#       7         datum = curs.fetchall()
#       8         conn.close()
#
# UndefinedTable: relation "user_mappings" does not exist
# LINE 1: SELECT *FROM user_mappings;
#                      ^

# %%
class Table:
    def __init__(self, columns):
        self.columns = columns 
        self.rows = []
    def __repr__(self):
        """pretty representation of the table: columns then rows""" 
        return str(self.columns) + "\n" + "\n".join(map(str, self.rows))
    def insert(self, row_values):
        if len(row_values) != len(self.columns):
            raise TypeError("wrong number of elements") 
            row_dict = dict(zip(self.columns, row_values)) 
            self.rows.append(row_dict)

# %% [markdown]
# First obtain data. Here I'm following the pattern found in _Docker for Data Science_ wherein my notebooks remain idempotent.

# %%
api = TikTokApi()

# %%
names = [n[1:] for n in names_list.split(',')]
names = map(lambda n: n.lower(), names)
#names = ['benthamite']
for i in range(0,6000):
    for name in names:
        print(name)
        try:
            tiktoks = api.byUsername(name, count=3)
        except Exception as e:
            print(e)
            continue
        t_time=str(datetime.datetime.now())
        print(len(tiktoks))
        print(t_time)
        for t in tiktoks:
            new_t=json.dumps(t)
            cur.execute('INSERT INTO tiktok (time,json) VALUES (%s,%s)', (t_time,new_t))
            #outfile.write('%s\t%s\t%s\n' % (t['id'],t_time,t))
        conn.commit()
        time.sleep(600 + randint(5, 15))
        #time.sleep(randint(5, 15))
cur.close()
conn.close()
# Out:
# ..amyana
# 'browser' object has no attribute 'browser'
# .l.o.l
# 'browser' object has no attribute 'browser'
# tripland
# 'browser' object has no attribute 'browser'
# saif_rayeen
# 'browser' object has no attribute 'browser'
# koronavirus.ss
# 'browser' object has no attribute 'browser'
# jor2dan99
# 'browser' object has no attribute 'browser'
# lorangray
# 'browser' object has no attribute 'browser'
# millieswaffles
# 'browser' object has no attribute 'browser'
# ezgizemvsp
# 'browser' object has no attribute 'browser'
# dreamerandachiever
# 'browser' object has no attribute 'browser'
# i_love_poop1
# 'browser' object has no attribute 'browser'
# antoniiog
# 'browser' object has no attribute 'browser'
# jenna1236
# 'browser' object has no attribute 'browser'
# sunflower_adopt.me_
# 'browser' object has no attribute 'browser'
# gracemeow
# 'browser' object has no attribute 'browser'
# xx_toba_xx
# 'browser' object has no attribute 'browser'
# trackerthekid
# 'browser' object has no attribute 'browser'
# iokasti_mix
# 'browser' object has no attribute 'browser'
# user94681479

# %%
data = db_query('firsttable')
class_event_df = pd.DataFrame(data, columns=['user_id', 'event_id', 'event_name','user_action'])
class_event_df.head(3)
# Out:
#    user_id  event_id event_name user_action
# 0        1         1   Studio 1     CHECKIN
# 1        3         1   Studio 1    REGISTER
# 2        3         1       None    REGISTER

# %% [markdown]
# Side note: what's up with the missing `h` in `igh_class_events` 😂

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# #### SQL Answer:

# %% [markdown]
# ----
